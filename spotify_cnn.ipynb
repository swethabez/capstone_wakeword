# %% [markdown]
# <a href="https://colab.research.google.com/github/mnarasim/mle9_capstone/blob/develop/spotify_cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
import numpy as np
import sklearn
import torch
import torchaudio
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from tqdm.auto import tqdm
from sklearn.preprocessing import MinMaxScaler
import skimage.io
from PIL import Image
from google.colab import drive 
drive.mount('/content/drive')
import os
# Out:
# Mounted at /content/drive

# %%
'''
gauth = GoogleAuth()   
gauth.LocalWebserverAuth()
drive = GoogleDrive(gauth)  
# read false samples
false_dict = {'name':[], 'id':[]}
file_list = drive.ListFile({'q': "'{}' in parents and trashed=false".format('13yBGR5nWOgp_U-cbYSi5XZZ0Sr1JxQlj')}).GetList()
for file in file_list:

    false_dict['name'].append(file['title'])
    false_dict['id'].append(file['id'])
   

    
# read true samples
true_dict = {'name':[], 'id':[]}
file_list = drive.ListFile({'q': "'{}' in parents and trashed=false".format('1mUhbkiEhDEAZgfpoO85k9yNwnGDdmLR4')}).GetList()
for file in file_list:

    true_dict['name'].append(file['title'])
    true_dict['id'].append(file['id'])

'''
DRIVE_FOLDER = '/content/drive/My Drive/data/false/'
entries = [entry for entry in os.listdir(DRIVE_FOLDER) if os.path.isfile(os.path.join(DRIVE_FOLDER, entry))]
false_dict = {'name':[]}
for file in entries:

    false_dict['name'].append(file)
DRIVE_FOLDER = '/content/drive/My Drive/data/true/'
entries = [entry for entry in os.listdir(DRIVE_FOLDER) if os.path.isfile(os.path.join(DRIVE_FOLDER, entry))]
true_dict = {'name':[]}
for file in entries:

    true_dict['name'].append(file)

# %%
df1 = pd.DataFrame(false_dict)
df1['label'] = 0
df1['path'] = '/content/drive/My Drive/data/false/'

df2 = pd.DataFrame(true_dict)
df2['label'] = 1
df2['path'] = '/content/drive/My Drive/data/true/'
# combine both dataframes
df = pd.concat([df1,df2])
df = df.sample(frac=1, random_state=56).reset_index(drop=True)

print('The length of the dataset is: ', f'{df.shape[0]:,}')

labels = df['label'].unique()
df.head
# Out:
# The length of the dataset is:  1,375
# <bound method NDFrame.head of                    name  label                                 path
# 0      Mani_false56.wav      0  /content/drive/My Drive/data/false/
# 1     Mani_false438.wav      0  /content/drive/My Drive/data/false/
# 2     Mani_false473.wav      0  /content/drive/My Drive/data/false/
# 3      Mani_false39.wav      0  /content/drive/My Drive/data/false/
# 4           Mani235.wav      1   /content/drive/My Drive/data/true/
# ...                 ...    ...                                  ...
# 1370   Maninoise651.wav      1   /content/drive/My Drive/data/true/
# 1371    Maninoise39.wav      1   /content/drive/My Drive/data/true/
# 1372        Mani694.wav      1   /content/drive/My Drive/data/true/
# 1373  Mani_false319.wav      0  /content/drive/My Drive/data/false/
# 1374  Mani_false395.wav      0  /content/drive/My Drive/data/false/
#
# [1375 rows x 3 columns]>

# %%
#Split the dataset into train and test dataset
trainset, testset = train_test_split(df, test_size=0.25, random_state=100)

#read_file = drive.CreateFile({'id': trainset.iloc[0][1]})
#read_file.GetContentFile(trainset.iloc[0][0])

waveform = torchaudio.load(trainset.iloc[0][2] + trainset.iloc[0][0])[0]
sr = torchaudio.load(trainset.iloc[0][2] + trainset.iloc[0][0])[1]

# %%
#load data required 
class MyDataset(torch.utils.data.Dataset):
    def __init__(self, dataframe):
        self.dataframe = dataframe

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, index):
        row = self.dataframe.iloc[index]
        
    
        
        waveform = torchaudio.load(row['path'] + row["name"])[0]

   
        return (
            waveform, row["label"],row['name'], row['path']
        )

train = MyDataset(trainset)
test = MyDataset(testset)

# %%
new_sample_rate = 16000
transform = torchaudio.transforms.Resample(orig_freq=sr, new_freq=new_sample_rate)
transformed = transform(waveform)

# %%
def pad_sequence(batch):
    # Make all tensor in a batch the same length by padding with zeros
    batch = [item.t() for item in batch]
  
    batch = torch.nn.utils.rnn.pad_sequence(batch, batch_first=True, padding_value=0.)
    return batch.permute(0, 2, 1)


def collate_fn(batch):

    # A data tuple has the form:
    # waveform, label

    tensors, targets, name, ids = [], [], [], []

    # Gather in lists, and encode labels as indices
    for waveform, label, n, i in batch:
        tensors += [waveform]
        label = torch.tensor(label)
    
        targets += [label]
        name.append(n)
        ids.append(i)

    # Group the list of tensors into a batched tensor
    tensors = pad_sequence(tensors)
    targets = torch.stack(targets)
    #name = torch.stack(name)

    return tensors, targets, name, ids

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
batch_size = 250

if device == "cuda":
    num_workers = 1
    pin_memory = True
else:
    num_workers = 0
    pin_memory = False

train_loader = torch.utils.data.DataLoader(
    train,
    batch_size=batch_size,
    shuffle=True,
    collate_fn=collate_fn,
    num_workers=num_workers,
    pin_memory=pin_memory,
)
test_loader = torch.utils.data.DataLoader(
    test,
    batch_size=batch_size,
    shuffle=False,
    drop_last=False,
    collate_fn=collate_fn,
    num_workers=num_workers,
    pin_memory=pin_memory,
)
# Out:
# cuda

# %%
class M5(nn.Module):
    def __init__(self, n_input=1, n_output=35, stride=16, n_channel=32):
        super().__init__()
        self.conv1 = nn.Conv1d(n_input, n_channel, kernel_size=80, stride=stride)
        self.bn1 = nn.BatchNorm1d(n_channel)
        self.pool1 = nn.MaxPool1d(4)
        self.conv2 = nn.Conv1d(n_channel, n_channel, kernel_size=3)
        self.bn2 = nn.BatchNorm1d(n_channel)
        self.pool2 = nn.MaxPool1d(4)
        self.conv3 = nn.Conv1d(n_channel, 2 * n_channel, kernel_size=3)
        self.bn3 = nn.BatchNorm1d(2 * n_channel)
        self.pool3 = nn.MaxPool1d(4)
        self.conv4 = nn.Conv1d(2 * n_channel, 2 * n_channel, kernel_size=3)
        self.bn4 = nn.BatchNorm1d(2 * n_channel)
        self.pool4 = nn.MaxPool1d(4)
        self.fc1 = nn.Linear(2 * n_channel, n_output)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(self.bn1(x))
        x = self.pool1(x)
        x = self.conv2(x)
        x = F.relu(self.bn2(x))
        x = self.pool2(x)
        x = self.conv3(x)
        x = F.relu(self.bn3(x))
        x = self.pool3(x)
        x = self.conv4(x)
        x = F.relu(self.bn4(x))
        x = self.pool4(x)
        x = F.avg_pool1d(x, x.shape[-1])
        x = x.permute(0, 2, 1)
        x = self.fc1(x)
        return F.log_softmax(x, dim=2)


model = M5(n_input=transformed.shape[0], n_output=len(labels))
model.to(device)
print(model)


def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)


n = count_parameters(model)
print("Number of parameters: %s" % n)
# Out:
# M5(
#   (conv1): Conv1d(1, 32, kernel_size=(80,), stride=(16,))
#   (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool1): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv1d(32, 32, kernel_size=(3,), stride=(1,))
#   (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool2): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv1d(32, 64, kernel_size=(3,), stride=(1,))
#   (bn3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool3): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   (conv4): Conv1d(64, 64, kernel_size=(3,), stride=(1,))
#   (bn4): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool4): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=64, out_features=2, bias=True)
# )
# Number of parameters: 24770

# %%
optimizer = optim.Adam(model.parameters(), lr=0.01, weight_decay=0.0001)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.1)  # reduce the learning after 20 epochs by a factor of 10

# %%
def train(model, epoch, log_interval):
    model.train()
    for batch_idx, (data, target,name, paths) in enumerate(train_loader):

        
        data = data.to(device)
        target = target.to(device)
        name = target.to(device)
        paths = target.to(device)
        # apply transform and model on whole batch directly on device
        data = transform(data)
        output = model(data)

        # negative log-likelihood for a tensor of size (batch x 1 x n_output)
        loss = F.nll_loss(output.squeeze(), target)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # print training stats
        if batch_idx % log_interval == 0:
            print(f"Train Epoch: {epoch} [{batch_idx * len(data)}/{len(train_loader.dataset)} ({100. * batch_idx / len(train_loader):.0f}%)]\tLoss: {loss.item():.6f}")

        # update progress bar
        pbar.update(pbar_update)
        # record loss
        losses.append(loss.item())

# %%
def number_of_correct(pred, target):
    # count number of correct predictions
    return pred.squeeze().eq(target).sum().item()


def get_likely_index(tensor):
    # find most likely label index for each element in the batch
    return tensor.argmax(dim=-1)

def correct_ones_name(pred, target, name):
  
    pred = pred.squeeze()

    
    mask = torch.eq(pred, target)
    mask = mask.tolist()

    result = [x for x, y in zip(name, mask) if y == True]
 
    return result

def correct_ones_path(pred, target, paths):
  
    pred = pred.squeeze()

    
    mask = torch.eq(pred, target)
    mask = mask.tolist()

    result = [x for x, y in zip(paths, mask) if y == True]
 
    return result

def test(model, epoch):
    model.eval()
    correct = 0
    correct_tensors=[]
    
    d = '/content/drive/My Drive/data/results/'
    entries = [entry for entry in os.listdir(d) if os.path.isfile(os.path.join(d, entry))]
    for f in entries:
      try:
        os.remove(d + f)
      except OSError:
        pass


    i=0
    for data, target,name, paths in test_loader:
        i = i + 1
  
        
        data = data.to(device)
        target = target.to(device)

        # apply transform and model on whole batch directly on device
        data = transform(data)
        output = model(data)

        pred = get_likely_index(output)
       
        correct_name = correct_ones_name(pred, target,name)
        correct_path = correct_ones_path(pred, target,paths)
       
      
        df2 = pd.DataFrame(data = correct_name, columns=['name'])
        df3 = pd.DataFrame(data = correct_path, columns=['path'])
        df4 = pd.concat([df2, df3], axis=1)
        
        p = d+ 'data'+str(i)+'.csv'
        #df4.to_csv('data'+str(i)+'.csv')
        with open(p, 'w', encoding = 'utf-8-sig') as f:
          df4.to_csv(f)
     

        correct += number_of_correct(pred, target)

        # update progress bar
        pbar.update(pbar_update)

    print(f"\nTest Epoch: {epoch}\tAccuracy: {correct}/{len(test_loader.dataset)} ({100. * correct / len(test_loader.dataset):.0f}%)\n")

# %%
log_interval = 20
n_epoch = 25

pbar_update = 1 / (len(train_loader) + len(test_loader))
losses = []

# The transform needs to live on the same device as the model and the data.
transform = transform.to(device)
with tqdm(total=n_epoch) as pbar:
    for epoch in range(1, n_epoch + 1):
        train(model, epoch, log_interval)
        test(model, epoch)
        scheduler.step()

# Let's plot the training loss versus the number of iteration.
# plt.plot(losses);
# plt.title("training loss");
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# Train Epoch: 1 [0/1031 (0%)]	Loss: 0.331231
#
# Test Epoch: 1	Accuracy: 205/344 (60%)
#
# Train Epoch: 2 [0/1031 (0%)]	Loss: 0.274833
#
# Test Epoch: 2	Accuracy: 276/344 (80%)
#
# Train Epoch: 3 [0/1031 (0%)]	Loss: 0.140926
#
# Test Epoch: 3	Accuracy: 294/344 (85%)
#
# Train Epoch: 4 [0/1031 (0%)]	Loss: 0.109798
#
# Test Epoch: 4	Accuracy: 297/344 (86%)
#
# Train Epoch: 5 [0/1031 (0%)]	Loss: 0.054793
#
# Test Epoch: 5	Accuracy: 286/344 (83%)
#
# Train Epoch: 6 [0/1031 (0%)]	Loss: 0.045714
#
# Test Epoch: 6	Accuracy: 325/344 (94%)
#
# Train Epoch: 7 [0/1031 (0%)]	Loss: 0.105642
#
# Test Epoch: 7	Accuracy: 332/344 (97%)
#
# Train Epoch: 8 [0/1031 (0%)]	Loss: 0.080342
#
# Test Epoch: 8	Accuracy: 329/344 (96%)
#
# Train Epoch: 9 [0/1031 (0%)]	Loss: 0.091670
#
# Test Epoch: 9	Accuracy: 335/344 (97%)
#
# Train Epoch: 10 [0/1031 (0%)]	Loss: 0.077798
#
# Test Epoch: 10	Accuracy: 338/344 (98%)
#
# Train Epoch: 11 [0/1031 (0%)]	Loss: 0.044731
#
# Test Epoch: 11	Accuracy: 339/344 (99%)
#
# Train Epoch: 12 [0/1031 (0%)]	Loss: 0.039405
#
# Test Epoch: 12	Accuracy: 338/344 (98%)
#
# Train Epoch: 13 [0/1031 (0%)]	Loss: 0.046411
#
# Test Epoch: 13	Accuracy: 336/344 (98%)
#
# Train Epoch: 14 [0/1031 (0%)]	Loss: 0.012811
#
# Test Epoch: 14	Accuracy: 336/344 (98%)
#
# Train Epoch: 15 [0/1031 (0%)]	Loss: 0.032092
#
# Test Epoch: 15	Accuracy: 336/344 (98%)
#
# Train Epoch: 16 [0/1031 (0%)]	Loss: 0.023767
#
# Test Epoch: 16	Accuracy: 337/344 (98%)
#
# Train Epoch: 17 [0/1031 (0%)]	Loss: 0.018390
#
# Test Epoch: 17	Accuracy: 336/344 (98%)
#
# Train Epoch: 18 [0/1031 (0%)]	Loss: 0.066029
#
# Test Epoch: 18	Accuracy: 336/344 (98%)
#
# Train Epoch: 19 [0/1031 (0%)]	Loss: 0.035336
#
# Test Epoch: 19	Accuracy: 339/344 (99%)
#
# Train Epoch: 20 [0/1031 (0%)]	Loss: 0.044796
#
# Test Epoch: 20	Accuracy: 334/344 (97%)
#
# Train Epoch: 21 [0/1031 (0%)]	Loss: 0.012463
#
# Test Epoch: 21	Accuracy: 336/344 (98%)
#
# Train Epoch: 22 [0/1031 (0%)]	Loss: 0.057318
#
# Test Epoch: 22	Accuracy: 336/344 (98%)
#
# Train Epoch: 23 [0/1031 (0%)]	Loss: 0.032336
#
# Test Epoch: 23	Accuracy: 337/344 (98%)
#
# Train Epoch: 24 [0/1031 (0%)]	Loss: 0.009351
#
# Test Epoch: 24	Accuracy: 337/344 (98%)
#
# Train Epoch: 25 [0/1031 (0%)]	Loss: 0.053212
#
# Test Epoch: 25	Accuracy: 338/344 (98%)

# %%
d = '/content/drive/My Drive/data/results/'
df_res1 = pd.read_csv(d+'data1.csv')
df_res2 = pd.read_csv(d+'data2.csv')
df_final = pd.concat([df_res1, df_res2])
df_final.head(4)
# Out:
#    Unnamed: 0               name                                 path
# 0           0   Mani_false50.wav  /content/drive/My Drive/data/false/
# 1           1        Mani233.wav   /content/drive/My Drive/data/true/
# 2           2  Mani_false307.wav  /content/drive/My Drive/data/false/
# 3           3        Mani306.wav   /content/drive/My Drive/data/true/

# %%
import speech_recognition as sr

for i in range(df_final.shape[0]):

     
     name_audio = df_final.iloc[i][1]

     print(name_audio)
    
     r = sr.Recognizer()
     with sr.WavFile(df_final.iloc[i][2] + name_audio) as source:              
        audio = r.record(source)                        

        try:
            print("Transcription: " + r.recognize_google(audio))   
        except Exception as e:
            print("Error: " + str(e))
# Out:
# Mani_false50.wav
# Transcription: they could barely see the boy
# Mani233.wav
# Transcription: weed killer do you know what he likes his food plane gifts for 7 year
# Mani_false307.wav
# Transcription: all you've got to do is talk to him
# Mani306.wav
# Transcription: 1/4 brain what should I watch
# Mani292 (1).wav
# Transcription: Seafood brain how does Amazon deploy recommendation system
# Maninoise47.wav
# Transcription: Fayetteville train when did Michael Jordan retire from basketball
# Mani_false74.wav
# Transcription: I'll be back in a minute
# Mani_false506.wav
# Transcription: it left a greenish streak that glowed for some seconds
# Mani_false140.wav
# Transcription: he's talking like a child
# Mani_false299.wav
# Transcription: sadly my dream of becoming a squirrel Whisperer may never happen
# Mani_false286.wav
# Transcription: it's required an explanation I'm just as sweet Universe meets as it travels through endless time
# Mani351 (1).wav
# Transcription: u.s. open starts on August 29th 11:30 when does it
# Maninoise83.wav
# Transcription: pay for trainers Arizona
# Mani_false428.wav
# Transcription: across the Sands many times someone of the camel drivers one night
# Mani396 (2).wav
# Transcription: is Disneyland in Florida better or California Highway 43 and how long does it
# Maninoise674.wav
# Transcription: a fourth grade when does the movie come out on Netflix
# Mani44.wav
# Transcription: headphones brain when is the NBA season starting
# Mani_false504.wav
# Transcription: go to ask me why I don't know why
# Mani397.wav
# Transcription: go to Disneyland the best to visit Disneyland
# Mani_false530.wav
# Transcription: I wish I could go back to the hospital
# Mani_false111.wav
# Transcription: why I was sent down here
# Mani_false211.wav
# Transcription: the Englishman was unable to sleep one night
# Mani_false494.wav
# Transcription: among these people were a couple of cyclists The Gardener employed sometimes and Adele carrying a baby
# Mani_false362 (1).wav
# Transcription: my name is Melchizedek said the old man
# Mani394 (1).wav
# Transcription: 1/4 brain is Batman stronger Superman
# Mani_false266.wav
# Transcription: I myself heard nothing of that
# Mani_false403.wav
# Transcription: she's a feisty little ferret
# Mani_false354.wav
# Transcription: I need you to be spontaneous he asked me how to dim dim
# Mani340.wav
# Transcription: what goes into making a racket headphones vein who makes the best 10
# Maninoise91.wav
# Transcription: Capleton is an Apple Store nearby
# Mani_false482.wav
# Transcription: he said
# Maninoise48.wav
# Transcription: Air Force Base. Best football player ever
# Mani_false186 (1).wav
# Transcription: they will fascinating stories you told them leave it out is Destiny today end
# Maninoise60.wav
# Transcription: are 14 who's the best NBA player ever
# Mani_false238 (1).wav
# Transcription: they are so used to me that they know my schedule he muttered
# Mani_false90.wav
# Transcription: I don't care what you charge them with
# Mani_false581.wav
# Transcription: it means only that the heart does what it can to say
# Mani_false462.wav
# Transcription: adjusted his clothing and picked up his pouch
# Mani400 (1).wav
# Transcription: can we make ice cream at home today for free what is the best ice cream
# Mani622.wav
# Transcription: hey fourth grade are unicorns real
# Mani_false189.wav
# Transcription: troops don't pay taxes
# Mani_false443.wav
# Transcription: we must be good
# Mani690.wav
# Transcription: 1/4 red how do I start my blog
# Mani_false509 (1).wav
# Transcription: my text that was painted as public school problems
# Mani624.wav
# Transcription: hey fourth-grade are Apple watches waterproof
# Mani_false184.wav
# Transcription: Burlington be so lovely this time of year
# Mani702.wav
# Transcription: hey 4th brain what time is it
# Mani671.wav
# Transcription: 1/4 brain when is Lollapalooza
# Mani_false542.wav
# Transcription: help me find them
# Mani_false537.wav
# Transcription: I'll tell you why they did it
# Maninoise676.wav
# Transcription: a fourth grade dim the lights
# Mani32.wav
# Transcription: Air Force plane what's the weather today
# Mani695.wav
# Transcription: hey footprint why am I so tired
# Mani_false506 (1).wav
# Transcription: it left a greenish streak that glowed for some seconds
# Mani_false7.wav
# Transcription: it had told him to dig where his tears fell
# Mani4.wav
# Transcription: headphones brain when does the Emily class start
# Mani_false453.wav
# Transcription: well usually I learn more from my sheep than from books he answered
# Mani_false253 (1).wav
# Transcription: you find it and are far from the sandwich
# Mani262.wav
# Transcription: hey food bring what does SMH mean
# Mani_false153 (1).wav
# Transcription: a large portion of the cylinder had been uncovered
# Mani_false436.wav
# Transcription: appreciated you could create a concise table
# Mani26.wav
# Transcription: headphones bring is there an NBA game on TV tonight
# Maninoise3.wav
# Transcription: Fayetteville train do we have Emily class next week
# Mani71.wav
# Transcription: headphones brain when is the NFL season starting
# Mani_false164.wav
# Transcription: Englishmen didn't answer him directly
# Mani_false71.wav
# Transcription: so you think Roxanne
# Mani_false184 (1).wav
# Transcription: Burlington be so lovely this time of year
# Mani_false252.wav
# Transcription: when he was a child that man wanted to travel to
# Mani_false68.wav
# Transcription: it's that guy that is an egg
# Mani628 (1).wav
# Transcription: pay for friend once Father's Day
# Mani_false502 (2).wav
# Transcription: without the dataset the article is useless
# Mani_false420.wav
# Transcription: I want my husband to wander as free as the wind that shaves to Dunes
# Mani_false524.wav
# Transcription: he just got a new kite for his birthday
# Mani387.wav
# Transcription: if I was naughty how many legs does a caterpillar
# Mani700.wav
# Transcription: hey footprint how many goals has Messi scored
# Mani_false220.wav
# Transcription: 2 Days Later the match and spoke to the boy about the display
# Mani_false60 (1).wav
# Transcription: excuse you for what
# Maninoise9.wav
# Transcription: pay for trade who won the Warriors game last night
# Mani_false519.wav
# Transcription: the boy looked around him at the date palms
# Mani_false585.wav
# Transcription: the monk was irritated
# Mani_false302 (1).wav
# Transcription: then the thing came apart
# Mani79.wav
# Transcription: Haverhill train how many homeless does Pleasanton have
# Mani_false290.wav
# Transcription: listen to your heart
# Mani250.wav
# Transcription: April train what does Mercury in retrograde mean
# Mani329.wav
# Transcription: people doing what is the smallest country in the world
# Mani_false273.wav
# Transcription: the boy noticed that conversation
# Mani270.wav
# Transcription: April train how many calories in a banana
# Mani_false165.wav
# Transcription: he felt weighted down by the centuries of times in the pyramids being built
# Mani_false231 (1).wav
# Transcription: he felt uneasy at the man's presence
# Maninoise55.wav
# Transcription: Kentwood spring how hot it is right now
# Mani698.wav
# Transcription: hey 4th brand how do I write a resume
# Mani653 (1).wav
# Transcription: 1/4 braids how do I make money online
# Mani260.wav
# Transcription: 1/4 green what is the difference between a mutual fund and an ETF
# Mani300.wav
# Transcription: a foot sprain how do you find the missing number in a given integer array of 12
# Mani_false259.wav
# Transcription: my 7-year resume. Not drugs
# Mani_false491.wav
# Transcription: I know that sounds
# Mani278.wav
# Transcription: seafood Green how do you whiten teeth
# Mani_false338.wav
# Transcription: I'm not good enough to make this one up
# Mani623.wav
# Transcription: hey 4th brain are jellyfish immortal
# Maninoise687.wav
# Transcription: 1/4 and 17 minute timer
# Maninoise43.wav
# Transcription: Air Force Base when is the NFL season started
# Mani_false3.wav
# Transcription: everything I own would be destroyed
# Mani_false560.wav
# Transcription: you can have as many babies as you like
# Mani_false120.wav
# Transcription: I noticed that the boy aren't you
# Mani613.wav
# Transcription: hey fourth brain is Reddit down
# Mani_false32.wav
# Transcription: they look for the falling Mass but found nothing
# Maninoise691.wav
# Transcription: Case Western what is monkeypox
# Mani338.wav
# Transcription: Hippowdon how do you reject advice without in alienating your mentor
# Mani96.wav
# Transcription: headphones brain what's the time in India right now
# Mani_false82.wav
# Transcription: at least she knows how to behave at funerals
# Mani_false79.wav
# Transcription: and finally the f****** return with them
# Mani620.wav
# Transcription: 1/4 brand does rice have gluten
# Mani347 (1).wav
# Transcription: you did tell me what defeated hippo bank and dogs eat tomatoes
# Mani_false89.wav
# Transcription: stranger seemed satisfied he answer
# Mani_false126.wav
# Transcription: you have been stalking me
# Mani_false591.wav
# Transcription: the missing parent is called a polygon
# Mani333.wav
# Transcription: Hippowdon what's the weather today
# Maninoise36.wav
# Transcription: airport when when is Christmas
# Mani43.wav
# Transcription: headphones brain when is the NFL season starting
# Mani_false498.wav
# Transcription: we lit the Lantern and walked over to his house
# Mani_false521.wav
# Transcription: the problem is that they don't even realize that they're walking a new road everyday
# Maninoise644.wav
# Transcription: hey question what time is the Super Bowl today
# Mani_false297.wav
# Transcription: A+ me is also trying to come to terms with the fact I will be able to travel as much anymore
# Mani373.wav
# Transcription: a boyfriend who owns Google
# Maninoise688.wav
# Transcription: caseworker how many people are in the world
# Mani640.wav
# Transcription: hey 4th brand how many calories are in an egg
# Maninoise28.wav
# Transcription: is Motrin Windows to Emily.
# Mani_false355.wav
# Transcription: it was dropping off in Flakes and raining down on the stand
# Mani697.wav
# Transcription: 1/4 friend play Diplo radio
# Mani318.wav
# Transcription: don't think we'll get the package today headphones brain does FedEx deliver on Sundays
# Mani_false59.wav
# Transcription: there were mountains in the distance
# Mani_false405.wav
# Transcription: she was supposed to come down and get you
# Mani_false422.wav
# Transcription: don't ask me why I don't know why
# Mani_false406 (1).wav
# Transcription: artificial neural networks can do something very similar
# Mani_false579.wav
# Transcription: how should I know
# Mani677.wav
# Transcription: hey boyfriend play Premier League soccer highlights
# Mani_false189 (1).wav
# Transcription: troops don't pay taxes
# Mani223.wav
# Transcription: 1/4 braid how do you set pieces in chess
# Mani_false365 (1).wav
# Transcription: she said it on the shelf and they date
# Mani_false227.wav
# Transcription: I promised I would make my own decisions he said to himself
# Mani_false76 (1).wav
# Transcription: a large piece came off and still with loud and sharp noise
# Mani638.wav
# Transcription: hey 4th brand what's an adjective
# Mani659.wav
# Transcription: 1/4 brain how many ounces are in a cup
# Mani_false370.wav
# Transcription: if he abandons that Pursuit it's because it wasn't true love
# Mani7.wav
# Transcription: headphones brain what's a good kids movie that's playing right
# Maninoise625.wav
# Transcription: hey fourth grade are airpods waterproof
# Mani_false552.wav
# Error:
# Mani_false411.wav
# Transcription: Pizza is an Italian classic
# Mani326.wav
# Transcription: yeah helps creating video content in seconds airport remodel am in Tucson
# Mani_false15.wav
# Error:
# Mani_false447.wav
# Transcription: high humidity is making me sweat
# Mani_false175.wav
# Transcription: what are you selling
# Mani_false477.wav
# Transcription: a large piece suddenly came off and fell with a loud and sharp noise
# Mani644 (1).wav
# Transcription: 1/4 and what time is the Super Bowl tonight
# Mani_false464.wav
# Transcription: 2 years ago right here on this but I had a recurring dream to
# Mani242.wav
# Transcription: between what are recommended nonfiction books for 2022
# Maninoise679.wav
# Transcription: kforce spring find a bar near me
# Maninoise654.wav
# Transcription: a fourth grade how many days are in a year
# Maninoise626.wav
# Transcription: K-Swiss grey how far am I from the Shedd Aquarium
# Mani_false203 (1).wav
# Transcription: he had seen the shooting star and was persuaded that a meteorite slay somewhere nearby
# Maninoise56.wav
# Transcription: Air Force brain what's the weather in Pleasanton this weekend
# Mani12.wav
# Transcription: what's the weather next week for train
# Mani10.wav
# Transcription: headphones brain how hot it is right now
# Mani348.wav
# Transcription: it's picture day tomorrow we need closed 11:30 when does Gap close
# Maninoise0.wav
# Transcription: infiltrating what's the weather today
# Mani_false26.wav
# Transcription: don't say that again
# Mani_false178.wav
# Transcription: it must have fallen while I was sitting over
# Mani630 (1).wav
# Transcription: 1/4 brain how do I make pancakes
# Mani_false323.wav
# Transcription: the sea has lived on in the Shell because that's its destiny
# Mani_false25.wav
# Error:
# Mani_false181.wav
# Transcription: rest well tonight as if you were a warrior preparing for combat
# Mani_false533.wav
# Transcription: goodbye began to dig into the June
# Mani_false188 (1).wav
# Transcription: one can imagine these two covered with sand running out the little Street in the bright sunlight
# Mani_false60.wav
# Transcription: excuse you for what
# Mani363.wav
# Transcription: mom please pay for training when does Target open hey Fourth Plain
# Mani393.wav
# Transcription: how tall should a rb2 to be a national day for today
# Mani_false551.wav
# Transcription: he felt unsafe like during his first lesson in Driving School
# Mani_false401.wav
# Transcription: 21 always wanted to accomplish
# Mani_false335.wav
# Transcription: required them to stay with the people they loved
# Mani649 (2).wav
# Transcription: 1/4 brain how do I start a business
# Mani_false543.wav
# Transcription: it always gets me right here
# Mani_false277.wav
# Transcription: of course he's coming back here
# Mani_false566.wav
# Transcription: the wind has many names
# Maninoise85.wav
# Transcription: Air Force brain when is the NBA season starting
# Mani_false405 (1).wav
# Transcription: she was supposed to come down and get you
# Mani_false402.wav
# Transcription: did you say King Yost
# Mani_false518.wav
# Transcription: then he realized I had been distracted for a few moments looking at the stored
# Mani_false532.wav
# Transcription: shoot through the desk
# Mani345 (1).wav
# Transcription: people doing water some famous Ted Talks Of 2022
# Mani_false336.wav
# Transcription: one night the father had a dream
# Mani602.wav
# Transcription: how long do bears hibernate A4 French how many months does a bear hibernate
# Mani_false366.wav
# Transcription: she likes you
# Mani_false256.wav
# Transcription: who is your friend
# Mani_false400.wav
# Transcription: the forest burn for 13 days
# Mani9.wav
# Transcription: headford playing who won the Warriors game last night
# Mani_false76.wav
# Transcription: a large piece came off and still with loud and sharp noise
# Mani35.wav
# Transcription: headphones brain when is Labor Day
# Maninoise692.wav
# Transcription: 1/4 in what is Juneteenth holiday
# Mani_false283.wav
# Error:
# Mani_false52.wav
# Transcription: he needed someone to talk to so as to avoid thinking about the possibility of War
# Mani672.wav
# Transcription: hey 4th brain when is prime day
# Mani_false71 (1).wav
# Transcription: so you think Roxanne
# Mani_false212 (1).wav
# Transcription: Maine tomorrow said the boy
# Mani_false78.wav
# Transcription: the homeless seem to like soup
# Mani634.wav
# Transcription: pay for friend how do I draw a rose
# Mani_false421.wav
# Transcription: She's accused of stealing watch
# Mani692.wav
# Transcription: 1/4 brain what is Juneteenth holiday
# Mani339.wav
# Transcription: if I'd been what is the name of the dinosaur with a 3-month reharms
# Mani394 (3).wav
# Transcription: 1/4 brain is Batman stronger Superman
# Mani378.wav
# Transcription: it's Novak or Rafa the better tennis player hit for free
# Mani_false271.wav
# Transcription: the first baseman dropped the ball
# Mani_false369 (1).wav
# Transcription: I heard up regular humming sound from the pit
# Mani_false403 (1).wav
# Transcription: she's a feisty little ferret
# Mani_false254 (1).wav
# Transcription: I have already found my treasure
# Mani_false509.wav
# Transcription: my text that was painted as public school problems
# Mani327.wav
# Transcription: principal banned what does it mean in sports and how do I use swing
# Mani_false457.wav
# Transcription: you point to a trail of ants leading into the house
# Mani_false369.wav
# Transcription: I heard up regular humming sound from the pit
# Mani_false572.wav
# Transcription: until my wing went bad
# Mani646.wav
# Transcription: 1/4 brand how to how do I play poker
# Mani_false97.wav
# Transcription: off of you.
# Maninoise97.wav
# Transcription: hazeldene what's the drive time to LA from Pleasanton California
# Mani18.wav
# Transcription: headphones brain what when is Labor Day this year
# Mani_false153.wav
# Transcription: a large portion of the cylinder had been uncovered
# Maninoise40.wav
# Transcription: faithful train what's the weather in Pleasanton this weekend
# Mani_false376.wav
# Transcription: do you want to buy Krupp this Administration
# Mani631.wav
# Transcription: 1/4 grain how do I boil eggs
# Mani_false373.wav
# Transcription: Osceola of the stone how much is one cost say to his friend
# Mani_false125 (1).wav
# Transcription: I have no information about Rousseau I bought the movement of the tribes
# Mani_false504 (1).wav
# Transcription: go to ask me why I don't know why
# Maninoise13.wav
# Transcription: who is the number one NBA draft pick for Spain
# Maninoise647.wav
# Transcription: fourth grade how many steps are in a mile
# Maninoise667.wav
# Transcription: hey Porter why do people cry
# Mani_false439.wav
# Transcription: the boy found a peg in his hot thinking about the magician's daughter
# Mani_false407.wav
# Transcription: I see grateful for the time that we have spent together
# Mani352.wav
# Transcription: hey forthright why is the sky blue
# Mani_false510.wav
# Transcription: then spade and came out into the road
# Mani_false407 (1).wav
# Transcription: I see grateful for the time that we have spent together
# Mani_false493.wav
# Transcription: Gypsy Christmas present from a very dear friend of mine
# Maninoise629.wav
# Transcription: a fourth grade how old is Joe Biden
# Mani_false377.wav
# Transcription: I'm just a man who wanders a desert knows the Stars
# Mani298.wav
# Transcription: fo3 how do you find the duplicate number on a given integer Dory
# Mani_false444.wav
# Transcription: you're supposed to be the one that has all the answers
# Mani_false141.wav
# Transcription: the quicker the better
# Mani696.wav
# Transcription: 1/4 friend playing pool hall on Twitch
# Maninoise668.wav
# Transcription: pay for frames read me the news
# Mani637.wav
# Transcription: a boyfriend what's a verb
# Mani_false550.wav
# Transcription: nothing is terrific
# Maninoise52.wav
# Transcription: painful to bring when is the NBA season starting
# Mani_false499.wav
# Transcription: country Greg here
# Mani_false233.wav
# Transcription: it was a bundle of money
# Mani650 (1).wav
# Transcription: hey 4th brain how tall is
# Mani_false528.wav
# Transcription: I told you that you'll drink with a difficult one
# Mani_false429.wav
# Transcription: without responding to God and to the tent where he remained for sometime
# Mani244.wav
# Transcription: a food green where are dinosaur fossils found in North America
# Mani_false288.wav
# Error:
# Mani_false191.wav
# Transcription: the boy knew that he was referring to Fatima
# Maninoise46.wav
# Transcription: it was clean when is NBA Pinky
# Mani_false55.wav
# Transcription: no one attacks an oasis
# Mani_false237.wav
# Transcription: the thief wasn't there the owner brought him a cup of tea
# Mani76.wav
# Transcription: sportsbrain headphones brain where can I get Thai food right now
# Maninoise30.wav
# Transcription: infiltrating what's the weather today
# Mani625.wav
# Transcription: hey fourth grade are airpods waterproof
# Mani_false374.wav
# Transcription: that leaves the lions at the voice of the young arm
# Maninoise605.wav
# Transcription: a fourth grade how old are you
# Mani_false158.wav
# Transcription: there are rumors of chihuahuas he told them
# Mani319.wav
# Transcription: what spices go in the disheveled mean what cinnamon called in Telugu
# Mani_false431.wav
# Transcription: it was only when I got this close to it that the strangeness of it was all evident to me
# Mani33.wav
# Transcription: pay for train who won the Superbowl last year
# Mani633.wav
# Transcription: hey boyfriend how many days until Christmas
# Mani261.wav
# Transcription: what is the weather in Egypt like a food green what is the best time to visit the
# Mani_false598.wav
# Transcription: in those days very few people have any idea
# Mani_false223.wav
# Transcription: he looked at the stone he felt relief for some reason
# Mani_false114.wav
# Transcription: why the shortstop after the 10th no one else has tried to explain
# Maninoise45.wav
# Transcription: Air Force Band is Steph Curry the best player in NBA
# Mani_false239 (1).wav
# Transcription: the mall was irritated
# Mani390.wav
# Transcription: what were dragons real how many planets are there hey Fortran is Pluto
# Mani_false508.wav
# Transcription: I had to test your courage The Stranger said
# Mani_false160.wav
# Transcription: mosquito bits
# Maninoise27.wav
# Transcription: infiltrating who won the Superbowl last year
# Mani652 (1).wav
# Transcription: 1/4 brain how do I avoid burnout
# Maninoise74.wav
# Transcription: do you want headphones playing when is the NFL season starting
# Mani_false289.wav
# Transcription: he didn't want to cry with the other people there
# Mani235.wav
# Transcription: it would bring a garden does a free profit use
# Maninoise642.wav
# Transcription: a fourth grade how do you get rid of hiccups
# Mani269.wav
# Transcription: April drain how do you draw anime
# Mani_false237 (1).wav
# Transcription: the thief wasn't there the owner brought him a cup of tea
# Mani351.wav
# Transcription: u.s. open starts on August 29th 11:30 when does it
# Mani214.wav
# Transcription: use for a Fourth Plain what is CRM stock price
# Mani_false11.wav
# Transcription: you haven't seen anything yet
# Mani_false535.wav
# Transcription: why don't you fellows get your own news
# Mani_false80.wav
# Transcription: 4 months passed and the Shelf many customers
# Maninoise612.wav
# Transcription: 1/4 G is Mercury in retrograde
# Mani652 (2).wav
# Transcription: 1/4 brain how do I avoid burnout
# Mani_false486.wav
# Transcription: she went over to the hospital to call and Professor Davis
# Mani_false497.wav
# Transcription: he was just and good
# Mani_false105.wav
# Transcription: there is a way out
# Mani359.wav
# Transcription: hey boyfriend how how do you make slime
# Mani639.wav
# Transcription: 1/4 brand what is a noun
# Mani_false248.wav
# Transcription: an important difference is the amount of experiences that is to say Imports
# Mani_false193.wav
# Transcription: but that was simply because my I was tired
# Mani_false371.wav
# Transcription: everyone seemed very excited
# Mani320.wav
# Transcription: I don't think they're open for Labor Day headphones van are banks open today
# Mani232.wav
# Transcription: popular is it effective and safe weed killers if it's brain is it not
# Mani_false554.wav
# Transcription: what are these things he asked
# Mani0.wav
# Transcription: hippo train what's the weather today
# Mani61.wav
# Transcription: hey Porter brain what's the homeless population of Pleasanton
# Mani_false233 (1).wav
# Transcription: it was a bundle of money
# Mani_false219.wav
# Transcription: he saw that Fatima's eyes were filled with tears
# Mani621.wav
# Transcription: 1/4 braids are banks open today
# Mani52.wav
# Transcription: headphones brain when is the NBA season starting
# Maninoise650.wav
# Transcription: hey fourth grade how tall is he
# Mani_false170.wav
# Transcription: not see what you look like when your protest
# Maninoise17.wav
# Transcription: therefore Spring City have Emily class next week
# Mani397 (1).wav
# Transcription: go to Disneyland the best to visit Disneyland
# Mani_false218.wav
# Transcription: the model has effectively three fully connected layers
# Mani268.wav
# Transcription: people train how do you delete Facebook account
# Mani_false94.wav
# Transcription: hotel at the chronicle got the Laughlin has
# Maninoise670.wav
# Transcription: a four-stroke how tall is Kevin Hart
# Mani_false470.wav
# Transcription: he said he had never seen any like them
# Mani_false251.wav
# Transcription: at once she connected the two incidents
# Maninoise698.wav
# Transcription: caseworker how do I write a resume
# Mani1.wav
# Transcription: headphones brain is it going to rain tonight
# Mani_false113.wav
# Transcription: to come to town early to find a woman who could interpret this dream
# Mani364.wav
# Transcription: is it today if one friend what time is it
# Mani_false239.wav
# Transcription: the mall was irritated
# Mani75.wav
# Transcription: sportsbrain where can I get Indian food right now
# Mani_false472.wav
# Transcription: I cook drunk yesterday and thought I'd build a supercomputer
# Maninoise77.wav
# Transcription: skateboard games
# Mani_false251 (1).wav
# Transcription: at once she connected the two incidents
# Mani_false334.wav
# Transcription: the night was warm and I was thirsty
# Mani_false379.wav
# Transcription: it rest in this Arabian clothing of white linen especially for this day
# Mani_false562.wav
# Transcription: the old man Returns the book to the boys
# Mani_false88.wav
# Transcription: some of the grayish was falling off the circular Edge
# Maninoise2.wav
# Transcription: cancel train when does the NBA season start
# Mani_false325.wav
# Transcription: I understand that it is your data set and that it is new
# Mani_false478.wav
# Transcription: airplane Rose gracefully into the sky
# Mani_false209.wav
# Transcription: I'm going into the desert the man answered turning back to his reading
